tat
tbonestudio
teaforte
tenpintenwire
tforkent
the-gal-who-sold-tora
themamascloset
theman
threemamas
threexsixes
thriveofficial
tientientaiwan
tinnietiny
tinyscene
tojiki-tonya
tonymichelle
travelinhandmade
triwa
tsuei
tuosilver
turnturn2017
uconacrobatics
ultra-works
underthestone
urbaner
vasstudio
version-2
vintique-watch
vistax51donate
vitacraft
walco-design
wankapo
warm-garden
weavism
wednesdaytw
wei-metalsmit
wenti
wesmile-hugger
wesmile-zippyjamz
wildtreasure
wohobike
wolftea
woodman
woopapers
wvbluewen
xanadu0000
xcellent
yamazawa-kiyoshi
ycct
youpin
yu-1977
zecho
zellerlife
zingidea
zoom-taiwan
zugo
'''

# %%
# 去重複, 刪空格, 轉小寫
non_dup_sids_list = list(set(sid.strip().lower() for sid in sids_str.split('\n') if sid))
print non_dup_sids_list
# Out:
# ['paralife', 'sogon', 'jardinduminuit', 'rou', 'stayingwings', 'zecho', 'tojiki-tonya', '4u4u', 'recycle', 'dotsormore', 'madamrose', 'surprise', 'nike19830407', 'hacoa', 'minkstw', 'lo-v-e-ly', 'namaste-hanakana', 'qqcinc', 'boeffies', 'brooklyn-soap', 'p714', 'peej', 'dawoodesign', 'dearpo', '7teahouse', 'ecocolour01356', 'mm-moment', 'influxx', 'wvbluewen', 'hon-yeung', 'lishankumytea', 'tforkent', 'missbranches', 'erdaliving', 'hongkongoapes', 'wei-metalsmit', 'sophiarosedesign', 'lamusecybele', 'themamascloset', 'greenontw', 'hallmarkcards', 'anonymous1965', 'daughter', 'littdlework', 'ffsssoap', 'roger528', 'weavism', 'easygo', 'forestnoodles', 'jlhouse', '24bottleshk', 'qubefun', 'woopapers', 'iwood-design', 'the-gal-who-sold-tora', 'ippi', 'tonymichelle', 'kouhandmadejewellery', 'inblooom', 'ikoo', 'back-to-green', 'needosocks', 'shininglife', 'vitacraft', 'blooming', 'tat', 'hand-in-hand', 'forestchild2005', 'thriveofficial', 'cultu-re', 'junsuiacc', 'bad-duck', 'color-potte
# ...

# %%
# check corre
from pinkoi.models2.base import db02 as db
from mosql.util import in_operand
with db as cur:
    cur.execute('''
        select sid
        from store
        where sid in {}
    '''.format(in_operand(non_dup_sids_list)))
    checked_sids = [sid for sid, in cur.fetchall()]
# Out:
# - - - [22/Jan/2018:16:54:29 +0800] - - - - - [SQL] "0.003s" "select sid	        from store	        where sid in ('paralife', 'sogon', 'jardinduminuit', 'rou', 'stayingwings', 'zecho', 'tojiki-tonya', '4u4u', 'recycle', 'dotsormore', 'madamrose', 'surprise', 'nike19830407', 'hacoa', 'minkstw', 'lo-v-e-ly', 'namaste-hanakana', 'qqcinc', 'boeffies', 'brooklyn-soap', 'p714', 'peej', 'dawoodesign', 'dearpo', '7teahouse', 'ecocolour01356', 'mm-moment', 'influxx', 'wvbluewen', 'hon-yeung', 'lishankumytea', 'tforkent', 'missbranches', 'erdaliving', 'hongkongoapes', 'wei-metalsmit', 'sophiarosedesign', 'lamusecybele', 'themamascloset', 'greenontw', 'hallmarkcards', 'anonymous1965', 'daughter', 'littdlework', 'ffsssoap', 'roger528', 'weavism', 'easygo', 'forestnoodles', 'jlhouse', '24bottleshk', 'qubefun', 'woopapers', 'iwood-design', 'the-gal-who-sold-tora', 'ippi', 'tonymichelle', 'kouhandmadejewellery', 'inblooom', 'ikoo', 'back-to-green', 'needosocks', 'shininglife', 'vitacraft', 'blooming
# ...

# %%
print checked_sids
# Out:
# [u'teaforte']

# %%
if non_dup_sids_list != checked_sids:
    print u'錯誤清單'
    print set(non_dup_sids_list) - set(checked_sids)
# Out:
# 錯誤清單
# ...

# %%
#輸出成python 格式
print '\n'.join(['\'{}\','.format(sid) for sid in non_dup_sids_list])
# Out:
# 'vegetable80923',
# 'chihyu000',
